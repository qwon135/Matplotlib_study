# %% [markdown]
# # 13. 원 그래프(기본)

# %%
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.family']='Malgun Gothic'
matplotlib.rcParams['font.size']=12
matplotlib.rcParams['axes.unicode_minus']=False

# %% [markdown]
# ### 원 그래프 그리기(plt.pie)
# values, labels 값 설정
# 예시) 프로그래밍 언어 선호도

# %%
values=[30, 25, 20, 13, 10, 2]
labels=['Python', 'Java', 'Javascript', 'C#', 'C/C++', 'ETC']

plt.pie(values, labels=labels, autopct='%.1f%%') # autopct 사용하여 비율 표시 
plt.show()

# %% [markdown]
# #### 원 그래프 시작 부분 변경 (startangle=)

# %%
plt.pie(values, labels=labels, autopct='%.1f%%',startangle=90) # 90도 부분의 그래프 부터 시작
plt.show()

# %% [markdown]
# #### 반 시계 방향으로 원 그래프 그리기 (counterclock)

# %%
plt.pie(values, labels=labels, autopct='%.1f%%',counterclock=False)
plt.show()

# %% [markdown]
# ### 간격 띄워 강조하기 (explode)

# %%
values=[30, 25, 20, 13, 10, 2]
labels=['Python', 'Java', 'Javascript', 'C#', 'C/C++', 'ETC']
# explode=[0.2, 0.1, 0, 0, 0, 0] 
explode=[0.05]*6

plt.pie(values, labels=labels, explode=explode)
plt.show()

# %% [markdown]
# ### 범례 넣기

# %%
plt.pie(values, labels=labels, explode=explode)
plt.legend(loc=(1.2, 0.3)) # loc 를 통해 위치조절
plt.show()

# %% [markdown]
# #### 범례에 제목 넣기

# %%
plt.pie(values, labels=labels, explode=explode)
plt.legend(loc=(1.2, 0.3), title='언어') 
plt.show()
